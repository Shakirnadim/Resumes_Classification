# %%
import glob     # to extract the paths under directory and sub-directories
import textract      # to read .docx files
from pdfminer.high_level import extract_text    # to read .pdf files
from win32com import client as wc     # to read .doc files
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
files3 = glob.glob('C:\\Users\\shaki\\project 2\\Resumes-20230309T061904Z-001\\Resumes\\**\\*.doc',recursive=True)
for i in files3:
    print(i)
# Out:
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_PavasGoswami.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_Vinay Reddy.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React JS Developer_AnjaniPriyadarshini.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_G Ananda Rayudu.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_Gangareddy.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_Priyanka Ramadoss.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_srinivasarao.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_Vinod Akkala.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\PeopleSoft DBA_Ganesh Alladi.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Finance_Arun Venu.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Finance_Pritam Biswas.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Finance_Rahul Ahuja.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft FSCM_R Ahmed.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Nazeer Basha.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Priyanka L.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Tatikonda Kiran Kumar.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Hari Krishna M_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Harikrishna Akula_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Hima Mendu_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\J. Sumanth Royal_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Madeeswar A_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Naresh Babu Cherukuri_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Punugoti Swetha_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\ShireeshKumar_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Sri Krishna S_Hexaware.doc
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Venkateswarlu B_Hexaware.doc

# %% [markdown]
# # paths of .docx files :

# %%
filesx = glob.glob('C:\\Users\\shaki\\project 2\\Resumes-20230309T061904Z-001\\Resumes\\**\\*.docx',recursive=True)
for i in filesx:
    print(i)
# Out:
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Internship_Ravali_Musquare Technologies (1).docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Internship_Susovan Bag_Musquare Technologies.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_Deepakreddy.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_Haripriya.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_Kamalakar Reddy.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_Naveen sadhu.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_Pragnya.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_Sarala Madasu-converted.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Developer_Thirupathiamma.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Dev_Krishna Kanth.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React Dev_Krishna Kanth_Musquare Technologies.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\React JS Developer_Venkatalakshmi (1)-converted.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Reactjs Developer_kambala sai surendra_Musquare Technologies.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Reactjs Developer_M Lokesh Babu_Musquare Technologies.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Reactjs Developer_M Lokesh.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Reactjs Developer_Pranish Sonone_Musquare Technologies.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Reactjs Developer_Ranga Gaganam_Musquare Technologies.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Reactjs Developer_Shaik Abdul Sharuk_Musquare Technologies.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_AnubhavSingh.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_Murali.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_SirazuddinMohammad.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft Admin_Varkala Vikas.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\PeopleSoft DBA_Vivekanand Sayana.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft FSCM_HariNarayana.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft FSCM_Murali.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft FSCM_PriyabrataHota.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Peoplesoft FSCM_SUJATHA.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Peoplesoft resumes\Resume_Subha Santosh_Peoplesoft FSCM.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Anil kumar.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\AradhanaTripathi[4_0].docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Buddha Vamsi.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\kamballapradeep.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Neeraj Mishra.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\premsai.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\PSyamKumar[2_3].docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Rajupavanakumari[2_10].docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Ramalakshmi K.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\RameshNataru[3_4].docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\SQL Developer Lightning insight\Vinod B.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\ChinnaSubbarayuduM_Hexaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Gopi Krishna_Hexaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Himaja G_(Hexaware).docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Jyotiverma_Heaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\MooraboyinaGuravaiah_Hexaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\P V Sai Krishna_ Hexaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\RahulM_Hexaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\RameshP_Hexaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Srikanth-Hexaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\SSKumar_Hexaware.docx
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\workday resumes\Vinay Kumar_Hexaware.docx

# %% [markdown]
# # paths of .pdf files :

# %%
files2 = glob.glob('C:\\Users\\shaki\\project 2\\Resumes-20230309T061904Z-001\\Resumes\\**\\*.pdf',recursive=True)
for i in files2:
    print(i)
# Out:
# C:\Users\shaki\project 2\Resumes-20230309T061904Z-001\Resumes\Reactjs Developer_Prabakaran_Musquare Technologies.pdf

# %% [markdown]
# # total number of files :

# %%
tot = files3 + filesx + files2
print('Total no. of extracted files =', len(tot))
# Out:
# Total no. of extracted files = 79

# %% [markdown]
# # Text Extraction of .doc files and converting it to pandas dataframe along with the filenames as categories :

# %%
files3 = glob.glob('C:\\Users\\shaki\\project 2\\Resumes-20230309T061904Z-001\\Resumes\\**\\*.doc',recursive=True)
res_list = []
df1 = pd.DataFrame(files3,columns=['category'])
df1 = df1['category'].str.split('\\').str[7]
df1.columns = ['category']
for i in files3:
    w = wc.Dispatch('Word.Application')
    doc = w.Documents.Open(i)
    #text = line.replace('\t', ' ') for line in doc.content().split('\r') if line
    res_list.append(doc.content())
    #print(res_list)

df3 = pd.DataFrame(res_list,columns=['resume_text'])
df3 = df3.join(df1)
df3
# Out:
#                                           resume_text  \
# 0   \r\r
# PROFILE\rSearching for the opportunity ...
# 1   Maryala Vinay Reddy\r\rProfessional Summary:\t...
# 2   CURRICULUM VITAE\r\r\r\rAnjani Priyadarshini\r...
# 3   \r\r\r\r\r\r\t\r\rProfile Summary:\t\t\t\t\t\t...
# 4   PeopleSoft Database Administrator\r           ...
# 5   Priyanka Ramadoss\r61/46, MountPleasant, \rCoo...
# 6   PEOPLESOFT ADMINISTRATOR\r\r\rSRINIVAS.K \t\t\...
# 7   Vinod Akkala                                  ...
# 8    PeopleSoft Admin/PeopleSoft DBA\r\rGanesh All...
# 9   Arun Venu\r\r  EXPERIENCE SUMMARY\t\r\rExperie...
# 10  Personal Details\t\t\r\rName\rPritam Biswas...
# 11  Rahul Ahuja\r---------------------------------...
# 12  \rR Ahmed                                     ...
# 13
# \r\r Hyderabad\rNazeer Basha\rSQL and Power...
# 14                                         SQL SER...
# 15  Career objective\r\t\rA rewarding opportunity ...
# 16  Hari Krishna M\r\r\rSummary:\rA result oriente...
# 17  Harikrishna Akula                             ...
# 18  HIMA.MENDU\r  \r\rCareer Objective\rTo continu...
# 19  \t\t\t\t\t\t\tName:\tJ. Sumanth Royal.\r\t\rP...
# 20  \t\t\t\t\tMadeeswar A\r\t\r\t\rPROFILE SUMMARY...
# 21  Name\t: Naresh Babu Cherukuri\r\rObjective:\rT...
# 22  \r\r\r3.3 years of IT experience as Workda...
# 23  Shireesh Balasani                             ...
# 24  \tWorkday Integration Consultant\r\rName      ...
# 25  Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...
#
#                                   category
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3     Peoplesoft Admin_G Ananda Rayudu.doc
# 4          Peoplesoft Admin_Gangareddy.doc
# 5   Peoplesoft Admin_Priyanka Ramadoss.doc
# 6        Peoplesoft Admin_srinivasarao.doc
# 7        Peoplesoft Admin_Vinod Akkala.doc
# 8         PeopleSoft DBA_Ganesh Alladi.doc
# 9         Peoplesoft Finance_Arun Venu.doc
# 10    Peoplesoft Finance_Pritam Biswas.doc
# 11      Peoplesoft Finance_Rahul Ahuja.doc
# 12             Peoplesoft FSCM_R Ahmed.doc
# 13                        Nazeer Basha.doc
# 14                          Priyanka L.doc
# 15               Tatikonda Kiran Kumar.doc
# 16             Hari Krishna M_Hexaware.doc
# 17          Harikrishna Akula_Hexaware.doc
# 18                 Hima Mendu_Hexaware.doc
# 19           J. Sumanth Royal_Hexaware.doc
# 20                Madeeswar A_Hexaware.doc
# 21      Naresh Babu Cherukuri_Hexaware.doc
# 22            Punugoti Swetha_Hexaware.doc
# 23              ShireeshKumar_Hexaware.doc
# 24              Sri Krishna S_Hexaware.doc
# 25            Venkateswarlu B_Hexaware.doc

# %%
df3.loc[0:2,'category'] = 'ReactJS Developer'
df3.loc[3:12,'category'] = 'Peoplesoft'
df3.loc[13:15,'category'] = 'SQL Developer'
df3.loc[16:25,'category'] = 'Workday'
df3
# Out:
#                                           resume_text           category
# 0   \r\r
# PROFILE\rSearching for the opportunity ...  ReactJS Developer
# 1   Maryala Vinay Reddy\r\rProfessional Summary:\t...  ReactJS Developer
# 2   CURRICULUM VITAE\r\r\r\rAnjani Priyadarshini\r...  ReactJS Developer
# 3   \r\r\r\r\r\r\t\r\rProfile Summary:\t\t\t\t\t\t...         Peoplesoft
# 4   PeopleSoft Database Administrator\r           ...         Peoplesoft
# 5   Priyanka Ramadoss\r61/46, MountPleasant, \rCoo...         Peoplesoft
# 6   PEOPLESOFT ADMINISTRATOR\r\r\rSRINIVAS.K \t\t\...         Peoplesoft
# 7   Vinod Akkala                                  ...         Peoplesoft
# 8    PeopleSoft Admin/PeopleSoft DBA\r\rGanesh All...         Peoplesoft
# 9   Arun Venu\r\r  EXPERIENCE SUMMARY\t\r\rExperie...         Peoplesoft
# 10  Personal Details\t\t\r\rName\rPritam Biswas...         Peoplesoft
# 11  Rahul Ahuja\r---------------------------------...         Peoplesoft
# 12  \rR Ahmed                                     ...         Peoplesoft
# 13
# \r\r Hyderabad\rNazeer Basha\rSQL and Power...      SQL Developer
# 14                                         SQL SER...      SQL Developer
# 15  Career objective\r\t\rA rewarding opportunity ...      SQL Developer
# 16  Hari Krishna M\r\r\rSummary:\rA result oriente...            Workday
# 17  Harikrishna Akula                             ...            Workday
# 18  HIMA.MENDU\r  \r\rCareer Objective\rTo continu...            Workday
# 19  \t\t\t\t\t\t\tName:\tJ. Sumanth Royal.\r\t\rP...            Workday
# 20  \t\t\t\t\tMadeeswar A\r\t\r\t\rPROFILE SUMMARY...            Workday
# 21  Name\t: Naresh Babu Cherukuri\r\rObjective:\rT...            Workday
# 22  \r\r\r3.3 years of IT experience as Workda...            Workday
# 23  Shireesh Balasani                             ...            Workday
# 24  \tWorkday Integration Consultant\r\rName      ...            Workday
# 25  Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...            Workday

# %% [markdown]
# # Text Extraction of .docx files and converting it to pandas dataframe along with the filenames as categories :

# %%
files1 = glob.glob('C:\\Users\\shaki\\project 2\\Resumes-20230309T061904Z-001\\Resumes\\**\\*.docx',recursive=True)
res_list1 = []
dfx = pd.DataFrame(files1,columns=['category'])
dfx = dfx['category'].str.split('\\').str[7]
dfx.columns = ['category']

for i in files1:
    a = textract.process(i)
    res_list1.append((a).decode('utf-8'))

dfr = pd.DataFrame(res_list1,columns=['resume_text'])

dfr = dfr.join(dfx)
dfr
# Out:
#                                           resume_text  \
# 0   Name: Ravali P \n\n\n\n                       ...
# 1   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 2   Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 3   HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 4   KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 5   Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 6   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 7   SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 8   Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 9   Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 10  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 11  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 12  Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 13  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 14  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 16  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 17  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 18  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 19  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 20  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 21  Classification: Internal\n\nClassification: In...
# 22  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 23  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 24  PeopleSoft Administration\n\n \n\nVivekanand S...
# 25  Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 26  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 27  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 28  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 29  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...
# 30  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 31  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 32  BUDDHA VAMSI                                  ...
# 33  KAMBALLA PRADEEP                              ...
# 34  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 35  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 36  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 37  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 38  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 39  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 40  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 41  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# 42  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 43  G Himaja\n\n                                  ...
# 44  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 45  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 46  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 47  Workday HCM  Techno functional Consultant     ...
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 49  Srikanth (WORKDAY hCM Consultant)\t           ...
# 50  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 51  Vinay kumar .v\nWorkday Functional Consultant\...
#
#                                      category
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20         Peoplesoft Admin_AnubhavSingh.docx
# 21               Peoplesoft Admin_Murali.docx
# 22   Peoplesoft Admin_SirazuddinMohammad.docx
# 23        Peoplesoft Admin_Varkala Vikas.docx
# 24      PeopleSoft DBA_Vivekanand Sayana.docx
# 25          Peoplesoft FSCM_HariNarayana.docx
# 26                Peoplesoft FSCM_Murali.docx
# 27        Peoplesoft FSCM_PriyabrataHota.docx
# 28               Peoplesoft FSCM_SUJATHA.docx
# 29  Resume_Subha Santosh_Peoplesoft FSCM.docx
# 30                            Anil kumar.docx
# 31                 AradhanaTripathi[4_0].docx
# 32                          Buddha Vamsi.docx
# 33                       kamballapradeep.docx
# 34                         Neeraj Mishra.docx
# 35                               premsai.docx
# 36                       PSyamKumar[2_3].docx
# 37                Rajupavanakumari[2_10].docx
# 38                         Ramalakshmi K.docx
# 39                     RameshNataru[3_4].docx
# 40                               Vinod B.docx
# 41           ChinnaSubbarayuduM_Hexaware.docx
# 42                 Gopi Krishna_Hexaware.docx
# 43                   Himaja G_(Hexaware).docx
# 44                    Jyotiverma_Heaware.docx
# 45         MooraboyinaGuravaiah_Hexaware.docx
# 46             P V Sai Krishna_ Hexaware.docx
# 47                       RahulM_Hexaware.docx
# 48                      RameshP_Hexaware.docx
# 49                     Srikanth-Hexaware.docx
# 50                      SSKumar_Hexaware.docx
# 51                  Vinay Kumar_Hexaware.docx

# %%
dfr.loc[0:1,'category'] = 'Internship'
dfr.loc[2:19,'category'] = 'ReactJS Developer'
dfr.loc[20:29,'category'] = 'Peoplesoft'
dfr.loc[30:40,'category'] = 'SQL Developer'
dfr.loc[41:51,'category'] = 'Workday'
dfr
# Out:
#                                           resume_text           category
# 0   Name: Ravali P \n\n\n\n                       ...         Internship
# 1   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         Internship
# 2   Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...  ReactJS Developer
# 3   HARIPRIYA BATTINA \n\nExperience as UI Develop...  ReactJS Developer
# 4   KAMALAKAR REDDY. A \n\nLinked In: https://www....  ReactJS Developer
# 5   Naveen Sadhu\n\n\n\n\n\nTitle: software develo...  ReactJS Developer
# 6   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...  ReactJS Developer
# 7   SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...  ReactJS Developer
# 8   Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...  ReactJS Developer
# 9   Ui-Developer/ React JS Developer \n\nNAME: KRI...  ReactJS Developer
# 10  Ui-Developer/ React JS Developer \n\nNAME: KRI...  ReactJS Developer
# 11  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...  ReactJS Developer
# 12  Venkatalakshmi Pedireddy\n\nSoftware Developer...  ReactJS Developer
# 13  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...  ReactJS Developer
# 14  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...  ReactJS Developer
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...  ReactJS Developer
# 16  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...  ReactJS Developer
# 17  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...  ReactJS Developer
# 18  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...  ReactJS Developer
# 19  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...  ReactJS Developer
# 20  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...         Peoplesoft
# 21  Classification: Internal\n\nClassification: In...         Peoplesoft
# 22  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         Peoplesoft
# 23  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...         Peoplesoft
# 24  PeopleSoft Administration\n\n \n\nVivekanand S...         Peoplesoft
# 25  Hari Narayana \t\t              \n\n\t\n\n\n\n...         Peoplesoft
# 26  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...         Peoplesoft
# 27  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...         Peoplesoft
# 28  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...         Peoplesoft
# 29  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...         Peoplesoft
# 30  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...      SQL Developer
# 31  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...      SQL Developer
# 32  BUDDHA VAMSI                                  ...      SQL Developer
# 33  KAMBALLA PRADEEP                              ...      SQL Developer
# 34  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...      SQL Developer
# 35  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...      SQL Developer
# 36  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...      SQL Developer
# 37  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...      SQL Developer
# 38  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...      SQL Developer
# 39  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...      SQL Developer
# 40  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...      SQL Developer
# 41  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...            Workday
# 42  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...            Workday
# 43  G Himaja\n\n                                  ...            Workday
# 44  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...            Workday
# 45  Mooraboyina Guravaiah\n\nWorkday Integration S...            Workday
# 46  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...            Workday
# 47  Workday HCM  Techno functional Consultant     ...            Workday
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...            Workday
# 49  Srikanth (WORKDAY hCM Consultant)\t           ...            Workday
# 50  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...            Workday
# 51  Vinay kumar .v\nWorkday Functional Consultant\...            Workday

# %% [markdown]
# # Text Extraction of .pdf files and converting it to pandas dataframe along with the filenames as categories :

# %%
res_list2 = []
files2 = glob.glob('C:\\Users\\shaki\\project 2\\Resumes-20230309T061904Z-001\\Resumes\\**\\*.pdf',recursive=True)
dfp = pd.DataFrame(files2,columns=['category'])
dfp = dfp['category'].str.split('\\').str[7]
dfp.columns = ['category']

for i in files2:
    c = extract_text(i)
    res_list2.append(c)
    
dfd = pd.DataFrame(res_list2,columns=['resume_text'])
dfd = dfd.join(dfp)
dfd
# Out:
#                                          resume_text  category
# 0   \n\n \n\nName: M. Prabakaran \nTitle: UI Deve...       NaN

# %%
dfd.loc[0,'category'] = 'ReactJS Developer'
dfd
# Out:
#                                          resume_text           category
# 0   \n\n \n\nName: M. Prabakaran \nTitle: UI Deve...  ReactJS Developer

# %%
#Final Dataframe :

# %%
df = pd.concat([dfr, dfd, df3], axis=0,ignore_index=1)
df
# Out:
#                                           resume_text           category
# 0   Name: Ravali P \n\n\n\n                       ...         Internship
# 1   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         Internship
# 2   Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...  ReactJS Developer
# 3   HARIPRIYA BATTINA \n\nExperience as UI Develop...  ReactJS Developer
# 4   KAMALAKAR REDDY. A \n\nLinked In: https://www....  ReactJS Developer
# ..                                                ...                ...
# 74  Name\t: Naresh Babu Cherukuri\r\rObjective:\rT...            Workday
# 75  \r\r\r3.3 years of IT experience as Workda...            Workday
# 76  Shireesh Balasani                             ...            Workday
# 77  \tWorkday Integration Consultant\r\rName      ...            Workday
# 78  Venkateswarlu.B\t\t\t\t\t\t\t\tWorkday Consult...            Workday
#
# [79 rows x 2 columns]

# %% [markdown]
# # Saving the file into CSV form:

# %%
df.to_csv("resumes.csv")

# %% [markdown]
# # Visualization of count of Categories of Resumes :

# %%
plt.figure(figsize=(16,8))
ax = sns.countplot(x='category',data=df, palette='rocket')
plt.xticks(rotation=45, fontsize=15);
plt.title('Count of Categories of Resumes',fontsize = 14, fontweight = 'bold');
for i in ax.containers:
    ax.bar_label(i,fontsize=15, fontweight='bold')
